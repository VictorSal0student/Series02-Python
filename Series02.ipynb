# %% [markdown]
# # Series02-Python : Sinusoidal Waves

# %% [markdown]
# The equation for a sinusoidal wave is given by:
#
# $$ y(t) = A \sin(2 \pi f t + \phi) $$
#
# Where:
# - \( y(t) \) is the displacement at time \( t \)
# - \( A \) is the amplitude (the peak value) of the wave
# - \( f \) is the frequency (the number of cycles per unit time)
# - \( \phi \) is the phase shift (the horizontal shift of the wave)
# - \( t \) is the time variable

# %%
# implement the sinusoidal wave equation in Python
import numpy as np
import matplotlib.pyplot as plt

# Parameters
A = 1.0            # Amplitude
T = 1.0            # Period in seconds
u = 2 * np.pi / T  # Angular frequency
phi = 0            # Phase shift

# Time array
n_periods = 1                       # Number of periods to display
Duration = n_periods * T            # Duration in seconds
t = np.linspace(0, Duration, 1000)  # Time from 0 to Duration

# Sinusoidal wave equation
y = A * np.sin(u * t + phi)

# Plotting the wave
plt.figure(figsize=(6, 4))
plt.plot(t, y, label='y(t) = A sin(ωt + φ)')
plt.title('Sinusoidal Wave')
plt.xlabel('Time (s)')
plt.ylabel('Displacement (y)')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Improved version of the plot
#
# The tasks to be performed are:
#     Add a second plot of a cosine function of t in the same figure
#     Add a legend to the plot
#     Add a second y axis to the plot
#     Add a second label to the y axis
#     Save the plot as a pdf file

# %%
# Add a second plot of a cosine function of t in the same figure
A_cos = 1.0                # Amplitude
T_cos = 1.0                # Period in seconds
u_cos = 2 * np.pi / T_cos  # Angular frequency
phi_cos = 0                # Phase shift for cosine
y_cos = A_cos * np.cos(u_cos * t + phi_cos)

# Plotting both sine and cosine waves
plt.figure(figsize=(6, 4))
plt.plot(t, y, label='y(t) = A sin(ωt + φ)')
plt.plot(t, y_cos, label='y(t) = A cos(ωt + φ)', linestyle='--')
plt.title('Sinusoidal Wave and Cosine Wave')
plt.xlabel('Time (s)')
plt.ylabel('Displacement (y)')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()

# Save the plot as a pdf file
plt.figure(figsize=(6, 4))
plt.plot(t, y, label='y(t) = A sin(ωt + φ)')
plt.plot(t, y_cos, label='y(t) = A cos(ωt + φ)', linestyle='--')   
plt.title('Sinusoidal Wave and Cosine Wave')
plt.xlabel('Time (s)')
plt.ylabel('Displacement (y)')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.grid()
plt.legend()
plt.savefig('sinusoidal_wave.pdf')

# %% [markdown]
# # Final version of the plot
#
# Create a function called sinusoid that :
#     takes as input all parameters that you need to define the sinusoid
#     returns a numpy array called x
# Use the function sinusoid to create two numpy arrays s1 and s2 with the two different frequencies
# Plot s1 and s2 as a function of t (as illustrated in the graph)

# %%
## Create a function that generates a sinusoidal waves (Co-Pilot version)
#   def generate_sinusoidal_wave(A, T, phi, n_periods=1, num_points=1000):
#       u = 2 * np.pi / T
#       Duration = n_periods * T
#       t = np.linspace(0, Duration, num_points)
#       y = A * np.sin(u * t + phi)
#   return t, y

## Create a function that generates a sinusoidal waves (My version)
def sinusoidal(Amplitude, pulsation, phase, time):
    """Generate a sinusoidal wave given the parameters:
    
    # Parameters:
    Amplitude : float
        The peak value of the wave
    pulsation : float
        The angular frequency of the wave
    phase : float
        The phase shift of the wave
    time : array
        The time variable
    # Returns:
    --------
    y : array
        The displacement value of the wave at each time point
    """
    y = Amplitude * np.sin(pulsation * time + phase)
    return y

A = 10
frequency = 1.0
u = 2 * np.pi * frequency
phi = 0
start_time = 0
end_time = 10
n_samples = 1000
t = np.linspace(start_time, end_time, n_samples)

sinus_signal = sinusoidal(A, u, phi, t)

# Plot the sinusoidal signal
plt.plot(t, sinus_signal)
plt.title('Sinusoidal Wave')
plt.xlabel('Time (s)')
plt.ylabel('Displacement (y)')
plt.grid()
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.show()
